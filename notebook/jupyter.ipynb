# %%
import pandas as pd

df2024 = pd.read_csv("ruea-tr-2024-ckan_mejora.csv", sep=";")
df2023 = pd.read_csv("ruea-tr-2023-ckan.csv", sep=";")
df2022 = pd.read_csv("ruea-tr-2022-ckan.csv", sep=";")

# %%
dfconcepcion24 = df2024[df2024['ciudad'] == 'Gran Concepción']

dfconcepcion24.head()
# Out:
#      id_comuna   año cantidad_toneladas  id_contaminantes  \
# 1753            2024        3607,526375                73
# 1754            2024         340,703413                73
# 1755            2024        116,8281922                73
# 1756            2024        80,17674555                73
# 1757            2024        322,6874597                73
#
#             contaminantes           tipo_vehiculo              tipo_emision  \
# 1753  Monóxido de carbono  Vehículos particulares  Tubo de Escape Vehiculos
# 1754  Monóxido de carbono  Vehículos particulares  Tubo de Escape Vehiculos
# 1755  Monóxido de carbono  Vehículos particulares  Tubo de Escape Vehiculos
# 1756  Monóxido de carbono  Vehículos particulares  Tubo de Escape Vehiculos
# 1757  Monóxido de carbono  Vehículos particulares  Tubo de Escape Vehiculos
#
#                ciudad                                tipo_vehiculo(ccf8)
# 1753  Gran Concepción  Vehículos livianos de pasajeros gasolineros Eu...
# ...

# %%
print(f"Las dimensiones son del csv son: {df2024.shape}\n")
# Out:
# Las dimensiones son del csv son: (47817, 9)

# %%
df2024.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47817 entries, 0 to 47816
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_comuna            47817 non-null  str
#  1   año                  47817 non-null  int64
#  2   cantidad_toneladas   47817 non-null  str
#  3   id_contaminantes     47817 non-null  int64
#  4   contaminantes        47817 non-null  str
#  5   tipo_vehiculo        47817 non-null  str
#  6   tipo_emision         47817 non-null  str
#  7   ciudad               47817 non-null  str
#  8   tipo_vehiculo(ccf8)  47817 non-null  str
# dtypes: int64(2), str(7)
# memory usage: 3.3 MB

# %%
print(f"Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:\n{df2024.dtypes}")
# Out:
# Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:
# id_comuna                str
# año                    int64
# cantidad_toneladas       str
# id_contaminantes       int64
# contaminantes            str
# tipo_vehiculo            str
# tipo_emision             str
# ciudad                   str
# tipo_vehiculo(ccf8)      str
# dtype: object

# %%
dfconcepcion24['id_comuna'].unique()
# Out:
# <StringArray>
# [' ']
# Length: 1, dtype: str

# %%
dfconcepcion23 = df2023[df2023['ciudad'] == 'Gran Concepción']

dfconcepcion23.head()
# Out:
#                       contaminantes  id_contaminantes           tipo_vehiculo  \
# 285702  Nitrógeno amoniacal (o NH3)                77  Vehículos particulares
# 285703                     Mercurio                67  Vehículos particulares
# 285704                 Metano (CH4)                69  Vehículos particulares
# 285705          Monóxido de carbono                73  Vehículos particulares
# 285706      Dióxido de azufre (SO2)                44  Vehículos particulares
#
#                     tipo_emision           ciudad cantidad_toneladas   año  \
# 285702  Tubo de Escape Vehiculos  Gran Concepción      4,955,583,909  2023
# 285703  Tubo de Escape Vehiculos  Gran Concepción           4.96E-03  2023
# 285704  Tubo de Escape Vehiculos  Gran Concepción      1,840,645,452  2023
# 285705  Tubo de Escape Vehiculos  Gran Concepción      1,111,568,609  2023
# 285706  Tubo de Escape Vehiculos  Gran Concepción        0,194751228  2023
#
# ...

# %%
dfconcepcion23['año'].unique()
# Out:
# array([2023])

# %%
print(f"Las dimensiones son del csv son: {df2023.shape}\n")
# Out:
# Las dimensiones son del csv son: (390560, 12)

# %%
df2023.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 390560 entries, 0 to 390559
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   contaminantes        390560 non-null  str
#  1   id_contaminantes     390560 non-null  int64
#  2   tipo_vehiculo        390560 non-null  str
#  3   tipo_emision         390560 non-null  str
#  4   ciudad               390560 non-null  str
#  5   cantidad_toneladas   390560 non-null  str
#  6   año                  390560 non-null  int64
#  7   region               390560 non-null  str
#  8   provincia            390560 non-null  str
#  9   comuna               390560 non-null  str
#  10  id_comuna            390560 non-null  int64
#  11  tipo_vehiculo(ccf8)  390560 non-null  str
# dtypes: int64(3), str(9)
# memory usage: 35.8 MB

# %%
print(f"Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:\n{df2023.dtypes}")
# Out:
# Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:
# contaminantes            str
# id_contaminantes       int64
# tipo_vehiculo            str
# tipo_emision             str
# ciudad                   str
# cantidad_toneladas       str
# año                    int64
# region                   str
# provincia                str
# comuna                   str
# id_comuna              int64
# tipo_vehiculo(ccf8)      str
# dtype: object

# %%
dfconcepcion22 = df2022[df2022['ciudad'] == 'Gran Concepción']

dfconcepcion22.head()
# Out:
#                       contaminantes  id_contaminantes           tipo_vehiculo  \
# 285672  Nitrógeno amoniacal (o NH3)                77  Vehículos particulares
# 285673                     Mercurio                67  Vehículos particulares
# 285674                 Metano (CH4)                69  Vehículos particulares
# 285675          Monóxido de carbono                73  Vehículos particulares
# 285676      Dióxido de azufre (SO2)                44  Vehículos particulares
#
#                     tipo_emision           ciudad      cantidad_toneladas  \
# 285672  Tubo de Escape Vehiculos  Gran Concepción  7089033987.00000000000
# 285673  Tubo de Escape Vehiculos  Gran Concepción           0.00708903000
# 285674  Tubo de Escape Vehiculos  Gran Concepción  2633069766.00000000000
# 285675  Tubo de Escape Vehiculos  Gran Concepción  1342525887.00000000000
# 285676  Tubo de Escape Vehiculos  Gran Concepción             0,247406783
#
# ...

# %%
dfconcepcion22['id_comuna'].unique()
# Out:
# array([8101, 8102, 8103, 8105, 8106, 8107, 8108, 8110, 8111, 8112])

# %%
print(f"Las dimensiones son del csv son: {df2022.shape}\n")
# Out:
# Las dimensiones son del csv son: (377591, 12)

# %%
df2022.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 377591 entries, 0 to 377590
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   contaminantes        377591 non-null  str
#  1   id_contaminantes     377591 non-null  int64
#  2   tipo_vehiculo        377591 non-null  str
#  3   tipo_emision         377591 non-null  str
#  4   ciudad               377591 non-null  str
#  5   cantidad_toneladas   377591 non-null  str
#  6   año                  377591 non-null  int64
#  7   region               377591 non-null  str
#  8   provincia            377591 non-null  str
#  9   comuna               377591 non-null  str
#  10  id_comuna            377591 non-null  int64
#  11  tipo_vehiculo(ccf8)  377591 non-null  str
# dtypes: int64(3), str(9)
# memory usage: 34.6 MB

# %%
print(f"Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:\n{df2022.dtypes}")
# Out:
# Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:
# contaminantes            str
# id_contaminantes       int64
# tipo_vehiculo            str
# tipo_emision             str
# ciudad                   str
# cantidad_toneladas       str
# año                    int64
# region                   str
# provincia                str
# comuna                   str
# id_comuna              int64
# tipo_vehiculo(ccf8)      str
# dtype: object
