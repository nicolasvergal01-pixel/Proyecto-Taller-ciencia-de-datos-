# %%
# %pip install pandas

# %%
import pandas as pd

df2024 = pd.read_csv(r".\ruea-tr-2024-ckan_mejora.csv", sep=";")
df2023 = pd.read_csv(r".\ruea-tr-2023-ckan.csv", sep=";")
df2022 = pd.read_csv(r".\ruea-tr-2022-ckan.csv", sep=";")
print("Datos listos")

# %%
print(f"Las dimensiones son del csv son: {df2024.shape}\n")

# %%
df2024.info()

# %%
print(f"Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:\n{df2024.dtypes}")

# %%
df2024.describe()

# %%
df2024.isnull().sum()

# %%
df2024.apply(lambda col: (col.astype(str).str.strip() == "").sum())

# %%
df2024.duplicated().sum()

# %%
print(f"Las dimensiones son del csv son: {df2023.shape}\n")

# %%
df2023.info()

# %%
print(f"Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:\n{df2023.dtypes}")

# %%
df2023.isnull().sum()

# %%
df2023.describe()

# %%
df2023.apply(lambda col: (col.astype(str).str.strip() == "").sum())

# %%
df2023.duplicated().sum()

# %%
print(f"Las dimensiones son del csv son: {df2022.shape}\n")

# %%
df2022.info()

# %%
print(f"Los diferentes tipos de columnas y el tipo de dato que contiene el csv son:\n{df2022.dtypes}")

# %%
df2022.isnull().sum()

# %%
df2022.describe()

# %%
df2022.apply(lambda col: (col.astype(str).str.strip() == "").sum())

# %%
df2022.duplicated().sum()
